# %% [markdown]
# <a href="https://colab.research.google.com/github/gbsv25/Distribuicao-de-frequencia-e-Medidas-Centrais-utilizando-dados-do-ENEM-2019/blob/main/distribuicao_frequencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Distribuição de Frequência das Idades no ENEM 2019 - Sorocaba
#
# Este notebook analisa a distribuição das idades dos candidatos do ENEM 2019 na cidade de Sorocaba.
#
# ### 🔍 Passos da Análise:
# 1. Importação de Bibliotecas Python
# 2. Carregamento, Limpeza e filtragem dos dados 📂🛠️
# 3. Análise estatística 📊
# 4. Visualização dos dados 📈

# %% [markdown]
# # 1️⃣ IMPORTAÇÃO DE BIBLIOTECAS

# %%
# Importando as bibliotecas necessárias para análise de dados
import numpy as np
import pandas as pd
from collections import Counter

# %% [markdown]
# # 2️⃣ CARREGAMENTO E FILTRAGEM DE DADOS

# %%
# Montar o Google Drive para acessar os arquivos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Carregamento do dataset
enem_sp = pd.read_csv('/content/drive/MyDrive/projetos portifólio/enem_2019_tratado.csv',
                      sep=',', encoding='iso-8859-1')

# %%
# Exibir as 5 primeiras linhas
enem_sp.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL    RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1   parda
# 1     1,90E+11               São Paulo     17    F                1   parda
# 2     1,90E+11   São Bernardo do Campo     19    M                1   parda
# 3     1,90E+11              Embu-Guaçu     17    F                1   parda
# 4     1,90E+11               Guarulhos     23    F                1  branca
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO  ...  \
# 0                 1                1  não_respondeu             0  ...
# 1                 1                2        privada             0  ...
# 2                 1                2        pública             0  ...
# 3                 1                2        pública             0  ...
# 4                 1                1  não_respondeu             0  ...
#
#    NOTA_MT TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# ...

# %%
# Filtrando apenas os alunos de Sorocaba
enem_sorocaba = enem_sp.loc[enem_sp.NO_MUNICIPIO_RESIDENCIA == 'Sorocaba']

# %%
enem_sorocaba.head()
# Out:
#     NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL    RACA  \
# 42      1,90E+11                Sorocaba     27    F                1  branca
# 192     1,90E+11                Sorocaba     34    M                1  branca
# 226     1,90E+11                Sorocaba     24    F                1  branca
# 358     1,90E+11                Sorocaba     22    F                1  branca
# 409     1,90E+11                Sorocaba     34    F                2  branca
#
#      TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA  IN_TREINEIRO  ...  \
# 42                  1                1  não_respondeu             0  ...
# 192                 1                1  não_respondeu             0  ...
# 226                 1                1  não_respondeu             0  ...
# 358                 1                1  não_respondeu             0  ...
# 409                 1                1  não_respondeu             0  ...
#
# ...

# %%
#Mostrando o tamanho dos dados evidentes na cidade de Sorocaba
enem_sorocaba.shape
# Out:
# (8088, 29)

# %%
idades = enem_sorocaba['IDADE']

# %%
idades
# Out:
# 42        27
# 192       34
# 226       24
# 358       22
# 409       34
#           ..
# 499512    23
# 499592    17
# 499619    17
# 499646    18
# 499839    20
# Name: IDADE, Length: 8088, dtype: int64

# %% [markdown]
# 3️⃣ ANÁLISES ESTATÍSTICAS 📊
#
# Calculo de frequências (absoluta e relativa)

# %% [markdown]
# #### Calculo das frequências absoluta, relativa e percentual de uma variável numérica.
#
# Parâmetros: serie (pd.Series) - Coluna do DataFrame contendo os dados categorizados.
# Retorna: DataFrame com frequências absoluta, relativa e percentual.

# %%
freq_absoluta = Counter(idades)

# %%
freq_absoluta
# Out:
# Counter({27: 76,
#          34: 42,
#          24: 154,
#          22: 279,
#          28: 87,
#          30: 52,
#          19: 872,
#          25: 114,
#          17: 2993,
#          18: 1558,
#          29: 72,
#          32: 50,
#          20: 556,
#          36: 37,
#          21: 372,
#          23: 206,
#          26: 105,
#          39: 29,
#          38: 29,
#          37: 26,
#          41: 20,
#          31: 40,
#          33: 41,
#          54: 13,
#          40: 23,
#          47: 8,
#          43: 21,
#          50: 7,
#          35: 42,
#          61: 6,
#          60: 4,
#          42: 23,
#          53: 9,
#          49: 11,
#          46: 18,
#          45: 14,
#          48: 15,
#          64: 2,
#          57: 2,
#          52: 9,
#          51: 11,
#          16: 8,
#          44: 14,
#          56: 4,
#          58: 2,
#          65: 1,
#          59: 2,
#          15: 3,
#          62: 1,
#          73: 1,
#          14: 1,
#          70: 1,
# ...

# %%
freq_absoluta = pd.DataFrame.from_dict(freq_absoluta, orient='index')

# %%
freq_absoluta
# Out:
#        0
# 27    76
# 34    42
# 24   154
# 22   279
# 28    87
# 30    52
# 19   872
# 25   114
# 17  2993
# 18  1558
# 29    72
# 32    50
# 20   556
# 36    37
# 21   372
# 23   206
# 26   105
# 39    29
# 38    29
# 37    26
# 41    20
# 31    40
# 33    41
# 54    13
# 40    23
# 47     8
# 43    21
# 50     7
# 35    42
# 61     6
# 60     4
# 42    23
# 53     9
# 49    11
# 46    18
# 45    14
# 48    15
# 64     2
# 57     2
# 52     9
# 51    11
# 16     8
# 44    14
# 56     4
# 58     2
# 65     1
# 59     2
# 15     3
# 62     1
# 73     1
# 14     1
# 70     1
# 55     2

# %%
#Ordenar por ordem crescente de idade
freq_absoluta = freq_absoluta.sort_index(ascending=True)
freq_absoluta
# Out:
#        0
# 14     1
# 15     3
# 16     8
# 17  2993
# 18  1558
# 19   872
# 20   556
# 21   372
# 22   279
# 23   206
# 24   154
# 25   114
# 26   105
# 27    76
# 28    87
# 29    72
# 30    52
# 31    40
# 32    50
# 33    41
# 34    42
# 35    42
# 36    37
# 37    26
# 38    29
# 39    29
# 40    23
# 41    20
# 42    23
# 43    21
# 44    14
# 45    14
# 46    18
# 47     8
# 48    15
# 49    11
# 50     7
# 51    11
# 52     9
# 53     9
# 54    13
# 55     2
# 56     4
# 57     2
# 58     2
# 59     2
# 60     4
# 61     6
# 62     1
# 64     2
# 65     1
# 70     1
# 73     1

# %%
freq_relativa = freq_absoluta / freq_absoluta.sum()
freq_relativa
# Out:
#            0
# 14  0.000124
# 15  0.000371
# 16  0.000989
# 17  0.370054
# 18  0.192631
# 19  0.107814
# 20  0.068744
# 21  0.045994
# 22  0.034496
# 23  0.025470
# 24  0.019041
# 25  0.014095
# 26  0.012982
# 27  0.009397
# 28  0.010757
# 29  0.008902
# 30  0.006429
# 31  0.004946
# 32  0.006182
# 33  0.005069
# 34  0.005193
# 35  0.005193
# 36  0.004575
# 37  0.003215
# 38  0.003586
# 39  0.003586
# 40  0.002844
# 41  0.002473
# 42  0.002844
# 43  0.002596
# 44  0.001731
# 45  0.001731
# 46  0.002226
# 47  0.000989
# 48  0.001855
# 49  0.001360
# 50  0.000865
# 51  0.001360
# 52  0.001113
# 53  0.001113
# 54  0.001607
# 55  0.000247
# 56  0.000495
# 57  0.000247
# 58  0.000247
# 59  0.000247
# 60  0.000495
# 61  0.000742
# 62  0.000124
# 64  0.000247
# 65  0.000124
# 70  0.000124
# 73  0.000124

# %%
freq_relativa_perc = freq_relativa * 100
freq_relativa_perc
# Out:
#             0
# 14   0.012364
# 15   0.037092
# 16   0.098912
# 17  37.005440
# 18  19.263106
# 19  10.781405
# 20   6.874382
# 21   4.599407
# 22   3.449555
# 23   2.546983
# 24   1.904055
# 25   1.409496
# 26   1.298220
# 27   0.939664
# 28   1.075668
# 29   0.890208
# 30   0.642928
# 31   0.494560
# 32   0.618200
# 33   0.506924
# 34   0.519288
# 35   0.519288
# 36   0.457468
# 37   0.321464
# 38   0.358556
# 39   0.358556
# 40   0.284372
# 41   0.247280
# 42   0.284372
# 43   0.259644
# 44   0.173096
# 45   0.173096
# 46   0.222552
# 47   0.098912
# 48   0.185460
# 49   0.136004
# 50   0.086548
# 51   0.136004
# 52   0.111276
# 53   0.111276
# 54   0.160732
# 55   0.024728
# 56   0.049456
# 57   0.024728
# 58   0.024728
# 59   0.024728
# 60   0.049456
# 61   0.074184
# 62   0.012364
# 64   0.024728
# 65   0.012364
# 70   0.012364
# 73   0.012364

# %%
#Contando a frequência de cada idade na base de dados enem_sorocaba
frequencias_idade = enem_sorocaba['IDADE'].value_counts()

# %%
#Mostrando a contagem das idades
frequencias_idade
# Out:
# IDADE
# 17    2993
# 18    1558
# 19     872
# 20     556
# 21     372
# 22     279
# 23     206
# 24     154
# 25     114
# 26     105
# 28      87
# 27      76
# 29      72
# 30      52
# 32      50
# 34      42
# 35      42
# 33      41
# 31      40
# 36      37
# 39      29
# 38      29
# 37      26
# 42      23
# 40      23
# 43      21
# 41      20
# 46      18
# 48      15
# 44      14
# 45      14
# 54      13
# 51      11
# 49      11
# 52       9
# 53       9
# 16       8
# 47       8
# 50       7
# 61       6
# 60       4
# 56       4
# 15       3
# 57       2
# 64       2
# 58       2
# 59       2
# 55       2
# 65       1
# 62       1
# 73       1
# 14       1
# 70       1
# Name: count, dtype: int64

# %%
# 📌 Exibindo as 10 idades mais frequentes
frequencias_idade.head(10)
# Out:
# IDADE
# 17    2993
# 18    1558
# 19     872
# 20     556
# 21     372
# 22     279
# 23     206
# 24     154
# 25     114
# 26     105
# Name: count, dtype: int64

# %% [markdown]
# 4️⃣ VISUALIZAÇÃO DE DADOS (GRÁFICOS E HISTOGRAMAS)

# %% [markdown]
# **Matplotlib**

# %%
# Importa a biblioteca para visualização de gráficos
import matplotlib.pyplot as plt

# %% [markdown]
# ### Geramos um histograma com estilização aprimorada.
#
#     Parâmetros:
#     - serie (pd.Series) → Dados numéricos a serem visualizados.
#     - bins (int) → Número de intervalos no histograma (padrão = 10).
#     - titulo (str) → Título do gráfico.

# %%
# Foi gerado um histograma básico para visualizar a distribuição de idades
enem_sorocaba.IDADE.hist(bins=9) #Se refere ao número de colunas amostradas no gráfico
plt.title('Distribuição de Idades - Enem SP 2019 - Sorocaba')
plt.show()

# %%
# Criação de um histograma com mais ajustes visuais
plt.hist(enem_sorocaba.IDADE, 8, rwidth=1)
plt.title('Distribuição de Idades - Enem SP 2019 - Sorocaba')
plt.show()

# %%
# Histograma com estilização e importação de cor personalizada
from matplotlib import colors
plt.hist(enem_sorocaba.IDADE, 10, rwidth=1, color='Red', density = True, )
plt.title('Distribuição de Idades - Enem SP 2019 - Sorocaba')
plt.xlabel ('Idade')
plt.ylabel ('Frequência')
plt.show()

# %% [markdown]
# **Seaborn**

# %%
# Importa a biblioteca Seaborn para visualizações mais avançadas
import seaborn as sns

# %%
# Gera um histograma utilizando a biblioteca Seaborn
sns.distplot(enem_sorocaba['IDADE'], bins=8, color="brown", kde=True);
# Out:
# <ipython-input-78-5363bc0d931d>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=enem_sorocaba, x='IDADE', hue='SEXO', kde=True, bins=20)
plt.title('Distribuição de Idades por Sexo - ENEM Sorocaba')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.legend(title='Sexo', labels=['Masculino', 'Feminino'])
plt.show()

# %%
# Removendo warnings desnecessários que podem surgir devido a funções depreciadas ou mudanças em versões mais recentes das bibliotecas
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Gera um histograma usando Seaborn com probabilidade normalizada
sns.histplot(enem_sorocaba['IDADE'], bins=8, color="red", stat="probability");

# %%
sns.histplot(enem_sorocaba, x='IDADE', bins=8, color="orange", kde=False, stat="probability");

# %% [markdown]
# **Plotly**

# %%
import plotly.express as px #Importando a biblioteca Plotly Express para visualização interativa de dados
grafico =  px.histogram (enem_sorocaba,  x = "IDADE", nbins=10, histnorm='probability',)
grafico.update_layout(width=500,height=500,title_text='Distribuição de idades - Enem SP 2019 - Sorocaba')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "IDADE", nbins=10, histnorm='probability', color='SEXO')
grafico.update_layout(width=500,height=500,title_text='Distribuição de idades por sexo - Enem SP 2019 - Sorocaba', title_font_color = 'red')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "NOTA_MT", nbins=20, color='SEXO')
grafico.update_layout(width=500,height=500,title_text='Notas de Matemática por sexo - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "NOTA_CN", nbins=20, color='SEXO')
grafico.update_layout(width=500,height=500,title_text='Notas de Ciências Naturais por sexo - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "NOTA_LC", nbins=20, color='SEXO', histnorm='percent')
grafico.update_layout(width=500,height=500,title_text='Notas de Linguagens e Códigos por sexo - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "NOTA_CH", nbins=20, color='SEXO')
grafico.update_layout(width=500,height=500,title_text='Notas de Ciências Humanas por sexo - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "NOTA_REDACAO", nbins=20, color='SEXO', histnorm='probability')
grafico.update_layout(width=500,height=500,title_text='Notas de redação por sexo - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grafico =  px.histogram (enem_sorocaba,  x = "NOTA_REDACAO", nbins=20, color='RACA', histnorm='percent')
grafico.update_layout(width=800,height=800,title_text='Notas de redação por raça - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Identificando outliers no conjunto de dados.
plt.figure(figsize=(8,5))
sns.boxplot(x=enem_sorocaba['IDADE'])
plt.title('Boxplot da Distribuição de Idades dos Candidatos do ENEM em Sorocaba')
plt.xlabel('Idade')
plt.show()
